# %%
import datadotworld as dw
ds = dw.load_dataset('makeovermonday/2020w17-weekly-road-fuel-prices', auto_update=True)

# %%
ds.dataframes
# Out:
# LazyLoadedDict({'2012': LazyLoadedValue(<pandas.DataFrame>), '2013': LazyLoadedValue(<pandas.DataFrame>), '2014': LazyLoadedValue(<pandas.DataFrame>), '2015': LazyLoadedValue(<pandas.DataFrame>), '2016': LazyLoadedValue(<pandas.DataFrame>), '2017': LazyLoadedValue(<pandas.DataFrame>), '2018': LazyLoadedValue(<pandas.DataFrame>), '2019': LazyLoadedValue(<pandas.DataFrame>), '2020': LazyLoadedValue(<pandas.DataFrame>), 'all_years': LazyLoadedValue(<pandas.DataFrame>), 'all_years_2': LazyLoadedValue(<pandas.DataFrame>), 'charts': LazyLoadedValue(<pandas.DataFrame>), 'contents': LazyLoadedValue(<pandas.DataFrame>), 'methodology': LazyLoadedValue(<pandas.DataFrame>), 'summary': LazyLoadedValue(<pandas.DataFrame>)})

# %%
prices = ds.dataframes['all_years_2']

# %%
prices
# Out:
#                         date  uslp_pence_per_litre  usld_pence_per_litre
# 0                     6/9/03             74.590284             76.773394
# 1                    6/16/03             74.469143             76.689054
# 2                    6/23/03             74.423566             76.620546
# 3                    6/30/03             74.352421             76.505260
# 4                     7/7/03             74.283737             76.457376
# 5                    7/14/03             74.206577             76.408120
# 6                    7/21/03             75.065240             76.899144
# 7                    7/28/03             75.100855             76.861864
# 8                     8/4/03             75.124384             76.812342
# 9                    8/11/03             75.444516             77.080738
# 10                   8/18/03             75.808948             77.438590
# 11                   8/26/03             76.053011             77.675094
# ...

# %% [markdown]
# What is pence per litre?
